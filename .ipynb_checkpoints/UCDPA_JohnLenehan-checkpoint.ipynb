# %%
##########################################
#Step 0: Import libraries
##########################################
import os
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno

# %%
##########################################
#Step 1: Import data
##########################################

# %%
#Setting directory

os.chdir(r'C:\Users\jlenehan\OneDrive - Intel Corporation\Documents\0 - Data Science\Data Analytics Essentials\UCDPA_JohnLenehan\UCDPA_JohnLenehan')

# %%
#listing json URls and specifying chunksize
url_current = r'https://data.sfgov.org/resource/wg3w-h783.json?$limit=99999999' #current incident reports 2018-present

#using chunksize method to read in large datasets
sfpd_incident_current = pd.read_json(url_current) #reading current incident json

# %%
print(sfpd_incident_current.head())
# Out:
#          incident_datetime            incident_date       incident_time  \
# 0  2023-03-13T23:41:00.000  2023-03-13T00:00:00.000 2023-05-09 23:41:00
# 1  2023-03-01T05:02:00.000  2023-03-01T00:00:00.000 2023-05-09 05:02:00
# 2  2023-03-13T13:16:00.000  2023-03-13T00:00:00.000 2023-05-09 13:16:00
# 3  2023-03-13T10:59:00.000  2023-03-13T00:00:00.000 2023-05-09 10:59:00
# 4  2023-03-14T18:44:00.000  2023-03-14T00:00:00.000 2023-05-09 18:44:00
#
#    incident_year incident_day_of_week          report_datetime        row_id  \
# 0           2023               Monday  2023-03-13T23:41:00.000  125373607041
# 1           2023            Wednesday  2023-03-11T15:40:00.000  125379506374
# 2           2023               Monday  2023-03-13T13:17:00.000  125357107041
# 3           2023               Monday  2023-03-13T11:00:00.000  125355107041
# 4           2023              Tuesday  2023-03-14T18:45:00.000  125402407041
#
#    incident_id  incident_number report_type_code  ... latitude  longitude  \
# 0      1253736        230167874               VS  ...      NaN        NaN
# 1      1253795        236046151               II  ...      NaN        NaN
# 2      1253571        220343896               VS  ...      NaN        NaN
# 3      1253551        230174885               VS  ...      NaN        NaN
# 4      1254024        230176728               VS  ...      NaN        NaN
#
#   point :@computed_region_26cr_cadq :@computed_region_qgnn_b9vv  \
# 0   NaN                         NaN                         NaN
# 1   NaN                         NaN                         NaN
# 2   NaN                         NaN                         NaN
# 3   NaN                         NaN                         NaN
# 4   NaN                         NaN                         NaN
#
#   :@computed_region_jwn9_ihcz :@computed_region_h4ep_8xdi  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    :@computed_region_nqbw_i6c3  :@computed_region_n4xg_c4py  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   :@computed_region_jg9y_a9du
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 34 columns]

# %%
##########################################
#Step 2: Describe data
##########################################

# %%
#Describe recent incidents dataset
print(sfpd_incident_current.columns)
print(sfpd_incident_current.info())
print(sfpd_incident_current.describe())
print(sfpd_incident_current.shape)
# Out:
# Index(['incident_datetime', 'incident_date', 'incident_time', 'incident_year',
#        'incident_day_of_week', 'report_datetime', 'row_id', 'incident_id',
#        'incident_number', 'report_type_code', 'report_type_description',
#        'incident_code', 'incident_category', 'incident_subcategory',
#        'incident_description', 'resolution', 'police_district', 'filed_online',
#        'cad_number', 'intersection', 'cnn', 'analysis_neighborhood',
#        'supervisor_district', 'supervisor_district_2012', 'latitude',
#        'longitude', 'point', ':@computed_region_26cr_cadq',
#        ':@computed_region_qgnn_b9vv', ':@computed_region_jwn9_ihcz',
#        ':@computed_region_h4ep_8xdi', ':@computed_region_nqbw_i6c3',
#        ':@computed_region_n4xg_c4py', ':@computed_region_jg9y_a9du'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726914 entries, 0 to 726913
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_datetime            726914 non-null  object
#  1   incident_date                726914 non-null  object
#  2   incident_time                726914 non-null  datetime64[ns]
#  3   incident_year                726914 non-null  int64
#  4   incident_day_of_week         726914 non-null  object
#  5   report_datetime              726914 non-null  object
#  6   row_id                       726914 non-null  int64
#  7   incident_id                  726914 non-null  int64
#  8   incident_number              726914 non-null  int64
#  9   report_type_code             726914 non-null  object
#  10  report_type_description      726914 non-null  object
#  11  incident_code                726914 non-null  int64
#  12  incident_category            726283 non-null  object
#  13  incident_subcategory         726283 non-null  object
#  14  incident_description         726914 non-null  object
#  15  resolution                   726914 non-null  object
#  16  police_district              726914 non-null  object
#  17  filed_online                 146764 non-null  float64
#  18  cad_number                   563442 non-null  float64
#  19  intersection                 688122 non-null  object
#  20  cnn                          688122 non-null  float64
#  21  analysis_neighborhood        688122 non-null  object
#  22  supervisor_district          687743 non-null  float64
#  23  supervisor_district_2012     688002 non-null  float64
#  24  latitude                     688122 non-null  float64
#  25  longitude                    688122 non-null  float64
#  26  point                        688122 non-null  object
#  27  :@computed_region_26cr_cadq  688002 non-null  float64
#  28  :@computed_region_qgnn_b9vv  687340 non-null  float64
#  29  :@computed_region_jwn9_ihcz  673585 non-null  float64
#  30  :@computed_region_h4ep_8xdi  93471 non-null   float64
#  31  :@computed_region_nqbw_i6c3  151476 non-null  float64
#  32  :@computed_region_n4xg_c4py  92890 non-null   float64
#  33  :@computed_region_jg9y_a9du  7837 non-null    float64
# dtypes: datetime64[ns](1), float64(14), int64(5), object(14)
# memory usage: 188.6+ MB
# None
#        incident_year        row_id   incident_id  incident_number  \
# count  726914.000000  7.269140e+05  7.269140e+05     7.269140e+05
# mean     2020.105724  9.465380e+10  9.465378e+05     2.026488e+08
# std         1.580291  1.881702e+10  1.881702e+05     1.631089e+07
# min      2018.000000  6.186871e+10  6.186870e+05     0.000000e+00
# 25%      2019.000000  7.838198e+10  7.838192e+05     1.902467e+08
# 50%      2020.000000  9.459896e+10  9.459895e+05     2.005114e+08
# 75%      2021.000000  1.109448e+11  1.109448e+06     2.162070e+08
# max      2023.000000  1.273690e+11  1.273689e+06     9.814243e+08
#
#        incident_code  filed_online    cad_number           cnn  \
# count  726914.000000      146764.0  5.634420e+05  6.881220e+05
# mean    24561.326772           1.0  2.035202e+08  2.531749e+07
# std     25630.383601           0.0  2.460312e+07  3.094745e+06
# min      1000.000000           1.0  1.000000e+00  2.001300e+07
# 25%      6244.000000           1.0  1.908908e+08  2.395700e+07
# 50%      7041.000000           1.0  2.020914e+08  2.492500e+07
# 75%     51040.000000           1.0  2.136201e+08  2.647100e+07
# max     75030.000000           1.0  1.000000e+09  5.420300e+07
#
#        supervisor_district  supervisor_district_2012       latitude  \
# count        687743.000000             688002.000000  688122.000000
# mean              5.925350                  5.969358      37.769181
# std               2.838484                  2.808010       0.024485
# min               1.000000                  1.000000      37.707988
# 25%               3.000000                  3.000000      37.754668
# 50%               6.000000                  6.000000      37.775802
# 75%               9.000000                  8.000000      37.785829
# max              11.000000                 11.000000      37.829991
#
#            longitude  :@computed_region_26cr_cadq  \
# count  688122.000000                688002.000000
# mean     -122.423969                     6.698072
# std         0.026392                     3.332243
# min      -122.511295                     1.000000
# 25%      -122.434483                     3.000000
# 50%      -122.417716                     7.000000
# 75%      -122.407337                    10.000000
# max      -122.363743                    11.000000
#
#        :@computed_region_qgnn_b9vv  :@computed_region_jwn9_ihcz  \
# count                687340.000000                673585.000000
# mean                      4.914671                    53.041336
# std                       2.747453                    32.633024
# min                       1.000000                     1.000000
# 25%                       3.000000                    23.000000
# 50%                       5.000000                    50.000000
# 75%                       7.000000                    86.000000
# max                      10.000000                   117.000000
#
#        :@computed_region_h4ep_8xdi  :@computed_region_nqbw_i6c3  \
# count                      93471.0                151476.000000
# mean                           1.0                     2.341539
# std                            0.0                     1.376006
# min                            1.0                     1.000000
# 25%                            1.0                     1.000000
# 50%                            1.0                     3.000000
# 75%                            1.0                     3.000000
# max                            1.0                     5.000000
#
#        :@computed_region_n4xg_c4py  :@computed_region_jg9y_a9du
# count                      92890.0                       7837.0
# mean                           1.0                          1.0
# std                            0.0                          0.0
# min                            1.0                          1.0
# 25%                            1.0                          1.0
# 50%                            1.0                          1.0
# 75%                            1.0                          1.0
# max                            1.0                          1.0
# (726914, 34)
#          incident_datetime            incident_date       incident_time  \
# 0  2023-03-13T23:41:00.000  2023-03-13T00:00:00.000 2023-05-09 23:41:00
# 1  2023-03-01T05:02:00.000  2023-03-01T00:00:00.000 2023-05-09 05:02:00
# 2  2023-03-13T13:16:00.000  2023-03-13T00:00:00.000 2023-05-09 13:16:00
# 3  2023-03-13T10:59:00.000  2023-03-13T00:00:00.000 2023-05-09 10:59:00
# 4  2023-03-14T18:44:00.000  2023-03-14T00:00:00.000 2023-05-09 18:44:00
#
#    incident_year incident_day_of_week          report_datetime        row_id  \
# 0           2023               Monday  2023-03-13T23:41:00.000  125373607041
# 1           2023            Wednesday  2023-03-11T15:40:00.000  125379506374
# 2           2023               Monday  2023-03-13T13:17:00.000  125357107041
# 3           2023               Monday  2023-03-13T11:00:00.000  125355107041
# 4           2023              Tuesday  2023-03-14T18:45:00.000  125402407041
#
#    incident_id  incident_number report_type_code  ... latitude  longitude  \
# 0      1253736        230167874               VS  ...      NaN        NaN
# 1      1253795        236046151               II  ...      NaN        NaN
# 2      1253571        220343896               VS  ...      NaN        NaN
# 3      1253551        230174885               VS  ...      NaN        NaN
# 4      1254024        230176728               VS  ...      NaN        NaN
#
#   point :@computed_region_26cr_cadq :@computed_region_qgnn_b9vv  \
# 0   NaN                         NaN                         NaN
# 1   NaN                         NaN                         NaN
# 2   NaN                         NaN                         NaN
# 3   NaN                         NaN                         NaN
# 4   NaN                         NaN                         NaN
#
#   :@computed_region_jwn9_ihcz :@computed_region_h4ep_8xdi  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    :@computed_region_nqbw_i6c3  :@computed_region_n4xg_c4py  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   :@computed_region_jg9y_a9du
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 34 columns]
#
# SFPD Historical Incidents - Unique Values:
# incident_datetime:
# ['2023-03-13T23:41:00.000' '2023-03-01T05:02:00.000'
#  '2023-03-13T13:16:00.000' ... '2023-03-22T17:35:00.000'
#  '2023-03-06T16:41:00.000' '2023-03-22T15:28:00.000']
# 342223 unique values
# incident_date:
# ['2023-03-13T00:00:00.000' '2023-03-01T00:00:00.000'
#  '2023-03-14T00:00:00.000' ... '2020-09-13T00:00:00.000'
#  '2020-04-02T00:00:00.000' '2020-03-22T00:00:00.000']
# 1953 unique values
# incident_time:
# ['2023-05-09T23:41:00.000000000' '2023-05-09T05:02:00.000000000'
#  '2023-05-09T13:16:00.000000000' ... '2023-05-09T03:52:00.000000000'
#  '2023-05-09T05:56:00.000000000' '2023-05-09T08:13:00.000000000']
# 1440 unique values
# incident_year:
# [2023 2022 2018 2019 2021 2020]
# 6 unique values
# incident_day_of_week:
# ['Monday' 'Wednesday' 'Tuesday' 'Saturday' 'Thursday' 'Friday' 'Sunday']
# 7 unique values
# report_datetime:
# ['2023-03-13T23:41:00.000' '2023-03-11T15:40:00.000'
#  '2023-03-13T13:17:00.000' ... '2023-03-21T21:12:00.000'
#  '2023-03-22T17:51:00.000' '2023-03-22T09:40:00.000']
# 516857 unique values
# row_id:
# [125373607041 125379506374 125357107041 ... 125664272000 125687306303
#  125676707021]
# 726914 unique values
# incident_id:
# [1253736 1253795 1253571 ... 1256853 1256873 1256767]
# 606910 unique values
# incident_number:
# [230167874 236046151 220343896 ... 230200565 230202420 230202486]
# 524096 unique values
# report_type_code:
# ['VS' 'II' 'IS' 'VI']
# 4 unique values
# report_type_description:
# ['Vehicle Supplement' 'Coplogic Initial' 'Coplogic Supplement' 'Initial'
#  'Initial Supplement' 'Vehicle Initial']
# 6 unique values
# incident_code:
# [ 7041  6374  6372  6244  4134 71000 16780  6224 28150 16650 51040  4011
#   9164 62071 72000 71012 75025 63010  7045 62050 62040 64020  6313 62070
#  28165  7043 28135  3081  9320 75030 64085  9029  9031 26080 15200 61030
#  27195  7021 68069  3071  6240  4092 64070 75000 27170 19057  7046 12080
#   2004 16652 74000  7020 12168  6373 16662  7055  4013  5073 68000 26031
#   3023 10125  6314  3051 71013 62060 27090  4170  9027 19400 26030 16220
#  26100 28092 65020  5053  3074  7026 16110  9250  5041  5014  5071 28160
#   6312  7100 30140 60170 64010 65010 65030 65015 16230  4136 68050 71011
#  68030 16010  6361 19089 16654 16664  3474  9262  3421 16710 26040  6234
#  12030  7051  6302  9020  7056 11012  6364  9016 19050  6303  7054  6243
#   9024  5011  6154  7025  5042 51050 12015  5151  6151  5141  5143  4138
#   3012 68020 27130  6386  4081 15161  4083 27175  6381  6223 26150 64015
#  12027 12008  3021  5083  4014  7060  3424 71024  6304 16623  6363  6113
#  73010 15162 27070 26170  4104  4021 28166  4033 12100  4084 68060 28100
#  73000 27131 16622  6362 62010  4012  3011 15155  5173 26105  6114 13060
#  15151  6301 26029 51041  5013 10090  4073  5051 27176  7023 65016  3013
#  62020  6242  6112 15150 30155  3043 16430 51030  5153  3014  6241  9120
#   3401 16040 16210  9271  9267 15164 26142 65021  7053 12120  5043  6126
#  27177 62030 65060  6394 10010  5052 64080  4144 16030 14052 16420 15410
#  26028  6152 28164 26036 19024  5152  3423  4074  6230  3444 65050  6233
#  64065  6246  9340 14043  4154 19022  3494 10149  9030 15300  6111 19090
#  28010 31000  5081 27080  6150 27171  3072  7024 27065 19020  5082 10117
#   9264  5033 10045 27010 64060  3073 19055 26210  9173  9162 71010  5061
#  14045  5072  9040 26145 27110  6221  9015  3024  9026 10120  6371 14060
#   6125  6300  4114 15201 64072 27066 26148  3463 60010 28140  5012  9150
#   6220 10015 16666 64100  6316  5171 27068  6222 12173 16020  3042 16660
#  30210  3084 27030  5062 26032 28168 16621  6400  4082 64090 26039  6153
#   3041 28169 68055 61010 28161 60150  3414 60190  6214  3091  7200  5021
#  19060  5113 16642 16240 15400  9310  9269 26141 16632  6370  9034  6396
#   3492  5023 15095  7205 14040 28130  4023 10115 30190 61040  3082  3413
#   5031  9330 17130  4091 27300 12026  4093  3472 26200 26120 30030 14020
#  16625 60080  4072 13030 13020  7052  6124 19032 66050  3044  5063 27198
#  19010 62072  6360 65040 12167  3092 19081 16704 15160 10110 17020 19080
#   3471 12163  4064 30180 12010  9215  5172 27220  6343 28110  5251 16100
#   7044 12169  7203 19083  5271 65055 51020  9110 11016 28102  4080 16740
#   6310 19072  5142 16620 26035  4053  3464 30080  5241  3093 65070 30007
#  17070 30200 17030 65056 12172 13050 13115 27199 19082  3064  5111  1001
#   3061 60110 26135 28030 60060  3473 28080  6377 26020  7201 27100  5015
#  12171  4062 19030 16656  7022 30000 26149  6134 28020  3411 60070 64002
#   3054 64040 64012  4024  4022  6383 26160  3094 28180  9166 19028  3083
#   6231 16320 27145 27140 16120 10040 12130  3412 27122  6232 26061 19077
#  65057 12166  7042  9163 30020  6123  6378 73001  5022 26176 74020  6315
#  15152 12140 12040 28120 16720  2104  3063  7027 64000 61020 13111  9165
#   9060 27040 16410 64001 27060 64030 11014 13010  6395  1002 65014  5032
#   1000 27173  3431  9210 12075 26063 13075 74024 12110  3443 30009 14031
#  12055 16630  6344 16705 19075  6157  3461  5131  2003  6399  4054  2204
#   4061  4124 11017  6342 19076 27072  1160  9035 19100 12065 27201 12006
#  11013  4146 64011  7206  3034 12060  5161 12025 26143  6213 66030  9130
#  12150  6133  9167 27172  6398  3053  9161 72023 15303  6365 27020 13045
#  28136  3454 30170 10065 26037 27400 16712  6211 66010  6341  3491 28050
#  12164 16624  3033 68053  3022 16060 64017 17110  3422 65013  4063 68021
#   3031  5112 27401  2020 26034 14072 30150 19015  3442 16626  3052 27082
#   6132 27174 10145  5123  5122 12165  9261  2103 60090  5121 15153 10140
#   3493 65080 27050 16645 16634 16610  4145 10035 15401 16130 27185 19095
#   5133  6143 28167 13120  5162 13110  6110 28181 16730  9021 71019 14030
#  12020  6351 26178 17071 15165 26010 30010  9265 11015  6131 28040 12161
#   6212  9175 15154 19070 60120  6353 28103 10070 60160  1005 19031 27031
#  26140 60040 26180 30006  3062  6352 30130 15163 12050 26213 12070 15097
#   3032 30070 19025  9125  3451 27197  4076 28170  5163 16640 30192 16550
#   4026 30191  2102  6397 68057  6122 12024 15301  3433 27200  5231  1004
#  26177  1133 74022 26095 15302  6121  6120 16612  1062  6142 16760 13070
#  10055  6130 19062  3441 12090 64003 27210 30011 16646  3462 16310  2202
#   9270 26038 14041 66040 10025 11011 16050  4164  6141  5261  3452  6391
#  14042 10060  3484  9023 60180  4052 19026 10085  2201 30131  9266 10020
#  19065  9140 19053 16629 19086 12160  7202  9176  9010 30160 26211 16750
#  10075 27196 64014  7204  6375  9263  1003  3483 16711 26190 60020  2005
#   6340 19088 30120 16510 26175  3481  9171 26062  9022  5211 64013 27155
#  19084 64018  3434 19058 16636  3453  2002 16440 10050  3432  9268 17072
#   2001 27067 13072  4051  2101 13080  5361 30205 30110 60050 16540 30206
#  27165 26050 60030 19040 27120 28060 75011 12073  2203  9032 27071  5371
#  16520  6354 51010 16700]
# 844 unique values
# incident_category:
# ['Recovered Vehicle' 'Larceny Theft' 'Assault' 'Lost Property'
#  'Drug Violation' 'Malicious Mischief' 'Drug Offense' 'Non-Criminal'
#  'Fraud' 'Warrant' 'Other Offenses' 'Robbery' 'Case Closure'
#  'Other Miscellaneous' 'Stolen Property'
#  'Offences Against The Family And Children' 'Other' 'Motor Vehicle Theft'
#  'Traffic Collision' 'Suspicious Occ' 'Missing Person'
#  'Disorderly Conduct' 'Weapons Carrying Etc' 'Rape' 'Burglary'
#  'Fire Report' 'Arson' 'Vandalism' 'Suicide' 'Traffic Violation Arrest'
#  'Courtesy Report' 'Forgery And Counterfeiting' 'Weapons Offense'
#  'Embezzlement' 'Vehicle Misplaced' 'Miscellaneous Investigation'
#  'Suspicious' nan 'Prostitution' 'Vehicle Impounded' 'Sex Offense'
#  'Liquor Laws' 'Human Trafficking, Commercial Sex Acts' 'Gambling'
#  'Homicide' 'Civil Sidewalks' 'Motor Vehicle Theft?'
#  'Human Trafficking (A), Commercial Sex Acts' 'Weapons Offence'
#  'Human Trafficking (B), Involuntary Servitude']
# 49 unique values
# incident_subcategory:
# ['Recovered Vehicle' 'Larceny Theft - Other' 'Larceny - From Vehicle'
#  'Simple Assault' 'Lost Property' 'Drug Violation' 'Vandalism'
#  'Non-Criminal' 'Aggravated Assault' 'Fraud' 'Other' 'Other Offenses'
#  'Warrant' 'Larceny Theft - Bicycle' 'Robbery - Carjacking' 'Case Closure'
#  'Stolen Property' 'Trespass' 'Motor Vehicle Theft'
#  'Traffic Collision - Hit & Run' 'Robbery - Other' 'Suspicious Occ'
#  'Missing Person' 'Intimidation' 'Weapons Offense' 'Rape' 'Missing Adult'
#  'Burglary - Other' 'Fire Report' 'Arson' 'Robbery - Commercial'
#  'Theft From Vehicle' 'Extortion-Blackmail' 'Burglary - Commercial'
#  'Burglary - Residential' 'Suicide' 'Traffic Violation Arrest'
#  'Traffic Collision' 'Courtesy Report' 'Larceny Theft - Shoplifting'
#  'Forgery And Counterfeiting' 'Larceny - Auto Parts'
#  'Motor Vehicle Theft (Attempted)' 'Larceny Theft - From Building'
#  'Embezzlement' 'Disorderly Conduct' 'Vehicle Misplaced'
#  'Robbery - Street' 'Miscellaneous Investigation' 'Suspicious Package'
#  'Burglary - Hot Prowl' nan 'Larceny Theft - Pickpocket' 'Prostitution'
#  'Kidnapping' 'Vehicle Impounded' 'Liquor Law Violation' 'Sex Offense'
#  'Drunkenness' 'Stalking' 'Loitering'
#  'Human Trafficking, Commercial Sex Acts' 'Gambling' 'Homicide'
#  'Larceny Theft - Purse Snatch' 'Bribery' 'Rape - Attempted'
#  'Manslaughter' 'Bad Checks' 'Robbery - Residential' 'Arrest'
#  'Homicide - Excusable' 'Human Trafficking, Involuntary Servitude']
# 72 unique values
# incident_description:
# ['Vehicle, Recovered, Auto' 'Theft, Other Property, >$950'
#  'Theft, Other Property, $50-$200' 'Theft, From Locked Vehicle, >$950'
#  'Battery' 'Lost Property'
#  'Firearm, Armed While Possessing Controlled Substance'
#  'Theft, From Unlocked Vehicle, >$950'
#  'Malicious Mischief, Vandalism to Property' 'Methamphetamine Offense'
#  'Aided Case' 'Assault, Aggravated, W/ Gun'
#  'Access Card Information, Theft of' 'Probation Search' 'Found  Property'
#  'License Plate, Recovered' 'Search Warrant Service'
#  'Warrant Arrest, Local SF Warrant' 'Vehicle, Recovered, Truck'
#  'Warrant Arrest, Enroute To Outside Jurisdiction'
#  'Warrant Arrest, Enroute To Probation' 'Mental Health Detention'
#  'Theft, Bicycle, $200-$950' 'Parole Search'
#  'Malicious Mischief, Graffiti, Real or Personal Property'
#  'Vehicle, Recovered, Motorcycle' 'Phone Calls, Harassing'
#  'Carjacking with a Gun'
#  'Access Card, incl. Credit, Phone, ATM, Fraudulent Use of' 'Case Closure'
#  'Investigative Detention'
#  'False Personation to Receive Money or Property'
#  'Money, Property or Labor, Fraudulently Obtaining' 'Conspiracy'
#  'Domestic Violence (secondary only)' 'Death Report, Cause Unknown'
#  'Trespassing' 'Vehicle, Stolen, Auto'
#  'Traffic Collision, Hit & Run, Injury' 'Robbery, W/ Gun'
#  'Theft, From Locked Vehicle, Att.' 'Suspicious Occurrence' 'Found Person'
#  'Resisting, Delaying, or Obstructing  Peace Officer Duties'
#  'Terrorist Threats' 'Vehicle, Recovered, Other Vehicle'
#  'Firearm, Possession By Prohibited Person' 'Rape, Forcible, W/ Force'
#  'Methamphetamine, Possession For Sale' 'Missing Adult'
#  'Vehicle, Stolen & Recovered'
#  'Firearm, Loaded, in Vehicle, Possession or Use'
#  'Theft, Other Property, $200-$950'
#  'Controlled Substance, Possession For Sale'
#  'Vehicle, Recovered, Stolen outside SF'
#  'Assault, Aggravated, W/ Other Weapon'
#  'Burglary, Other Bldg., Unlawful Entry' 'Fire Report' 'Arson of Vehicle'
#  'Robbery, Comml. Establ. W/ Weapon' 'Theft, False Pretenses, Felony'
#  'Theft, Bicycle, >$950' 'Robbery, Residence, W/ Gun'
#  'License Plate, Stolen' 'Warrant Arrest, Enroute To Adult Authority'
#  'Theft, Lost Property, Petty' 'False Imprisonment' 'False Personation'
#  'Gang Related (secondary only)' 'Arson' 'Opiates, Possession For Sale'
#  'Extortion or Blackmail' 'Malicious Mischief, Adult Suspect'
#  'Driving, Reckless' 'Burglary, Store, Unlawful Entry' 'Robbery, W/ Force'
#  'Vehicle, Stolen, Other Vehicle' 'Heroin, Possession For Sale'
#  'Fraudulent Use Of Automated Teller Card'
#  'Burglary, Residence, Forcible Entry' 'Burglary, Vehicle (Arrest made)'
#  'Burglary, Other Bldg., Forcible Entry'
#  'Malicious Mischief, Vandalism to Vehicle' 'Theft, Bicycle, $50-$200'
#  'Vehicle, Tampering' 'Air Gun, Possession' 'Suicide By Jumping'
#  'Dog, Bite or Attack' 'Traffic Violation Arrest' 'Driving, Speeding'
#  'Driving, No License Issued' 'Opiates, Sale'
#  'Battery with Serious Injuries' 'Traffic Collision'
#  'License Plate, Found' 'Courtesy Report' 'Marijuana Offense'
#  'Theft, Shoplifting, <$50' 'Incident On School Grounds'
#  'Methamphetamine, Sale' 'Controlled Substance, Sale'
#  'Robbery, Att., W/ Force' 'Forgery & Counterfeiting (general)'
#  'Robbery, Att., Comm. Establ., W/ Gun'
#  'Narcotics Paraphernalia, Possession of' 'Extortion, Attempted'
#  'Theft, Vehicle Strip, >$950'
#  'Weapon, Deadly, Imitation or Laser Scope, Exhibiting'
#  'Vehicle, Stolen, Attempted' 'Theft, From Building, $50-$200'
#  'Checks, False, Making, Uttering or Possessing'
#  'Vehicle, Rental, Failure to Return'
#  'Stolen Property, Possession with Knowledge, Receiving'
#  'Theft, Shoplifting, >$950'
#  'Checks or Legal Instruments, Uttering Forged'
#  'Phone Calls, Threatening or Annoying' 'Theft, From Building, $200-$950'
#  'Vehicle, Misplaced' 'Theft, From Locked Vehicle, $200-$950'
#  'Fraudulent Game or Trick, Obtaining Money or Property'
#  'Burglary, Apartment House, Forcible Entry'
#  'Theft, From Person, >$950 (other than Pickpocket)'
#  'Vehicle, Stolen, Truck' 'Burglary, Residence, Att. Forcible Entry'
#  'Aided case, Naloxone Deployment' 'Weapon, Carrying Concealed'
#  'Burglary, Non-residential, Forcible Entry'
#  'Theft, From Person, <$50 (other than Pickpocket)'
#  'Burglary, Residence Under Constr, Forcible Entry'
#  'Burglary, Residence Under Constr, Unlawful Entry'
#  'Battery, former Spouse or Dating Relationship'
#  'Robbery, Street or Public Place, W/ Knife' 'Miscellaneous Investigation'
#  'Burglary Tools, Possession Of' 'Theft, Grand, of Firearm'
#  'Shooting into Inhabited Dwelling or Occupied Vehicle'
#  'Violation of Restraining Order'
#  'Firearm, Discharging in Grossly Negligent Manner'
#  'Evading a Police Officer Recklessly'
#  'Embezzlement from Dependent or Elder Adult by Caretaker'
#  'Theft, From Unlocked Vehicle, $200-$950' 'Parole Violation, Adult'
#  'Aided Case, Injured or Sick Person'
#  'Firearm, Discharging Within City Limits' 'Suspicious Package'
#  'Robbery, Comml. Establ., W/ Gun' 'Burglary, Hot Prowl, Unlawful Entry'
#  'Assault, Aggravated, W/ Force' 'Vehicle, Seizure Order Service'
#  'Robbery, Att., Comm. Establ., W/ Force'
#  'Stay Away or Court Order, Non-DV Related' 'Theft, From Building, >$950'
#  'Cocaine, Base/rock, Possession For Sale' 'Theft, Shoplifting, $200-$950'
#  'Theft, Pickpocket, $200-$950' 'Firearm, Turned In by Public'
#  'Violation of Stay Away Order' 'Impersonating A Police Officer'
#  'Probation Violation' 'Assault, Non-Aggravated'
#  'Assault, Att. Homicide, W/ Gun'
#  'Vandalism or Graffiti Tools, Possession'
#  'Assault, W/ Caustic Chemical to Injure or Disfigure'
#  'Firearm, Possession of Loaded'
#  'Firearm, Discharging at Unoccupied Bldg, Vehicle or Aircraft'
#  'Traffic Collision, Hit & Run, Property Damage'
#  'Malicious Mischief, Breaking Windows' 'Property for Identification'
#  'Burglary Tools, Possession Of w/prior' 'Cocaine, Possession For Sale'
#  'Theft, Shoplifting, $50-$200' 'Warrant Arrest, Enroute To US Marshall'
#  'Assault, Aggravated, W/ Knife' 'Robbery, Street or Public Place, W/ Gun'
#  'Restraining Order Notification/Service of Restraining Order'
#  'Burglary, Other Bldg. Under Constr., Unlawful Entry'
#  'Bomb Threat or False Report of Bomb' 'Theft, Pickpocket, >$950'
#  'Solicits For Act Of Prostitution'
#  'Stay Away Order Violation, DVU related' 'Theft, From Building, <$50'
#  'Arson, Attempted' 'Aided Case -Property for Destruction'
#  'Burglary, Apartment House, Unlawful Entry' 'Embezzlement (general)'
#  'Assault, Aggravated, On Police Off., W/ Other Weapon'
#  'Burglary, Store, Forcible Entry'
#  'Evading a Police Officer, Injury or Death' 'Vehicle, Stolen, Motorcycle'
#  'Driving, License Suspended or Revoked'
#  'Robbery, Street or Public Place, W/ Other Weapon'
#  'Warrant Arrest, Enroute To Dept. Of Corrections'
#  'Theft, From Locked Vehicle, $50-$200' 'Theft, Pickpocket, $50-$200'
#  'EPO or Restraining Order Violation, DVU related'
#  'Alcohol, Consuming In Public View'
#  'Robbery, Chain Store, W/ Other Weapon' 'Hallucinogenic, Sale'
#  'Shooting, Accidental' 'Burglary, Non-residential, Unlawful Entry'
#  'Robbery, Street or Public Place, W/ Force'
#  'Theft, From Locked Vehicle, <$50'
#  'Identification Card or Drivers License, Falsify or Display'
#  'Shoplifting, Force against Agent' 'Marijuana, Sales' 'Opiates Offense'
#  'Audiovisual (Video or Sound) Recordings, Unauthorized'
#  'Privacy, Invasion of  (general)' 'Gun Violence Restraining Order'
#  'Driving, Stunt Vehicle/Street Racing' 'Vehicle, Impounded'
#  'Weapon, Prohibited, Possession, Sale, Mfg., Import'
#  'Burglary, Residence, Unlawful Entry' 'Theft of Computers or Cell Phones'
#  'Evading a Police Vehicle or Bicycle' 'Warrant Arrest, Enroute To Parole'
#  'Driving While Under The Influence Of Drugs'
#  'Theft from Merchant or Library' 'Embezzlement, Petty Theft'
#  'Burglary, Store, Att. Forcible Entry' 'Suspicious Person'
#  'Battery, Sexual' 'Marijuana, Possession For Sale'
#  'Oral Copulation, Unlawful (Adult Victim)'
#  'Hallucinogenic,  Possession For Sale'
#  'Cryptocurrency Related Crime (secondary code only)'
#  'Flammable or Explosive Device, Possession'
#  'Theft, From Person, $50-$200 (other than Pickpocket)'
#  'Vandalism or Graffiti on or within 100 ft of Highway'
#  'Arson, Inhabited Dwelling' 'Disturbing The Peace, Fighting'
#  'Burglary, Non-residential, Att. Forcible'
#  'Robbery, Att., Comm. Establ. With Other Weapon'
#  'Assault, Aggravated, On Police Officer, W/ Force'
#  'Theft, Vehicle Strip, Attempted' 'Robbery, Att., Chain Store, W/ Force'
#  'Driving While Under The Influence Of Alcohol'
#  'Theft, Vehicle Strip, $200-$950' 'Suspicious Vehicle'
#  'License Plate or Tab, Theft of' 'Credit Application, Fraudulent'
#  'Phone Calls, Obscene' 'Battery, Of A Police Officer'
#  'Disturbing The Peace' 'Robbery,  ATM, Force, Att.'
#  'Counterfeit Money or Coins'
#  'Checks, Making or Uttering with Insufficient Funds'
#  'Hate Crime (secondary only)' 'Theft, Pickpocket, <$50'
#  'Alcohol, Under Influence Of In Public Place' 'Animal, Cruelty to'
#  'Federal Law Violation (general)' 'Burglary, Hot Prowl, Forcible Entry'
#  'Interfering, W/ Police Officer'
#  'Theft, From Person, Att. (other than Pickpocket)'
#  'Threat or Force to Resist Executive Officer' 'Robbery, W/ Knife'
#  'Vehicle, Stolen, Mobile Home or House Trailer'
#  'Identification To Peace Officer, False'
#  'Disturbing The Peace, Commotion'
#  'Burglary, Hot Prowl, Att. Forcible Entry'
#  'Theft, Trick And Device, Att.'
#  'Computer System, Accessing, Copying, or Damaging'
#  'Burglary, Hotel Room, Unlawful Entry'
#  'Embezzlement, Grand Theft By Employee'
#  'Defrauding Providers of Food, Fuel, Services, or Accommodations'
#  'Suspicious Act Towards Female' 'Robbery, W/ Other Weapon'
#  'Phone Calls, Threatening' 'Threatening School or Public Employee'
#  'False Claims, Presenting to Government'
#  'Falsification of Medical Records' 'License Plate, Lost'
#  'Burglary, Warehouse, Forcible Entry'
#  'Indecent Exposure, W/ Prior Conviction'
#  'Burglary, Other Bldg., Att. Forcible Entry'
#  'Checks, Money Orders, Completed, Fraudulent Possession'
#  'Theft, Lost Property, Grand'
#  'Public Nuisance, Maintaining After Notification'
#  'Theft, From Unlocked Vehicle, <$50' 'Forgery, Checks, Felony'
#  'Robbery, Comml. Establ., W/ Force'
#  'False Personation and Cheat Crimes (general)'
#  'Theft, False Pretenses, Misd.' 'Theft, Other Property, <$50'
#  'Obscene Matter (general)' 'Theft of Checks or Credit Cards'
#  'Theft, From Building, Att.' 'Assault, Non-Aggravated, Att.' 'Stalking'
#  'Suspicious Occurrence, possible Shots Fired'
#  'Other Offenses Against Public Justice' 'Kidnapping during Robbery'
#  'Robbery, Att., Bank, W/ Other Weapon' 'Suicide, Attempted'
#  'Malicious Mischief, Street Cars/Buses'
#  'Burglary, Apartment House, Att. Forcible Entry'
#  'Checks, Blank or Forged, Fraudulent Possession'
#  'Theft, From Unlocked Vehicle, Att.' 'Embezzlement, Grand Theft'
#  'Controlled Substance, Transportation' 'Auto Impounded'
#  'Theft, Bicycle, <$50, no serial number'
#  'Burglary, Other Bldg. Under Constr., Forcible Entry'
#  'False Report of Emergency' 'Theft, From Unlocked Vehicle, $50-$200'
#  'Ammunition, Poss. By Prohibited Person'
#  'Marijuana, Cultivating/Planting' 'Robbery, Chain Store, W/ Knife'
#  'Controlled Substance Offense' 'Park Code Violation (general)'
#  'Carjacking with Bodily Force'
#  'Rail Transit, Entering, Remaining, or Hindering Operation of'
#  'Burglary, Warehouse, Att. Forcible Entry' 'Arson, Commercial Building'
#  'Aerosol Container; Sale, Purchase or Possession of'
#  'Cocaine, Base/rock Offense' 'Theft of Animals (general)'
#  'Firearm, Discharging at Occupied Bldg, Vehicle, or Aircraft'
#  'Unusual Occurrence' 'Fire, Unlawfully Causing'
#  'Theft, From Person, $200-$950 (other than Pickpocket)'
#  'Robbery, Chain Store, W/ Gun'
#  'Graffiti on Government Vehicles or Public Transportation'
#  'Discharging Offensive or Injurious Substance in Public Area'
#  'Death, Accidental' 'Malicious Mischief, Tire Slashing'
#  'Suicide By Firearms' 'Robbery, Att., Street or Public Place, W/ Force'
#  'Suicide By Strangulation/Hanging' 'Theft, Motorcycle Strip, >$950'
#  'Robbery,  ATM, Gun' 'Vehicle Registration, False Evidence of'
#  'Burglary, Flat, Forcible Entry'
#  'Obstructing Public Thoroughfare  (or 647(c) PC)'
#  'Burglary, Apt Under Constr., Unlawful Entry'
#  'Amphetamine, Possession For Sale' 'Opiates, Transportation'
#  'ATM-related Crime (secondary code only)'
#  'Access Card, Possession of Lost or Stolen, with Intent to Use, Transfer, or Sell'
#  'Cellular or Cordless Phone Communications, Intercepting'
#  'Kidnapping (Adult victim)' 'Methadone, Possession For Sale'
#  'Theft of Other Property, Att.' 'Food Stamps, Misuse of'
#  'Theft of Utility Services' 'Robbery,  ATM, Knife, Att.'
#  'Burglary, Flat, Unlawful Entry' 'Tarasoff Report'
#  'Vehicle Alarm Code Grabbing Device, Possess or Use'
#  'Indecent Exposure (Adult victim)'
#  'Malicious Mischief, Annoying/Fictitious Phone Calls'
#  'Assault, Att. Homicide, W/ Other Weapon'
#  'Theft, Trick And Device, Felony'
#  'Municipal Police Code Violation (general)'
#  'Death Report, Natural Causes' 'Carjacking with a Knife'
#  'Robbery, Att., Street or Public Place, W/ Other Weapon'
#  'Burglary, Hotel Room, Forcible Entry'
#  'Access Card Counterfeiting Machinery, Possession of'
#  'Alcohol, Unlawful Transportation Of' 'Assault, Aggravated, W/ Semi Auto'
#  'State Code Misdemeanor (general)'
#  'Firearm, Discharging At An Inhabited Dwelling'
#  'Assault, Aggravated, On Police Officer, W/ Gun'
#  'Robbery, Att., W/ Knife' 'State Code Felony (general)'
#  'Injuring Phone, Cable TV, or Other Line'
#  'Defrauding Gas Station/Taxi Driver'
#  'Sex Offender, Failure To Register for Sexual Assault of Adult'
#  'Cocaine, Base/rock, Sale' 'Suicide By Laceration/Stabbing, Att.'
#  'Assault, Aggravated, On Police Officer, W/ Knife' 'Pimping' 'Pandering'
#  'Vehicle, Embezzled' 'Theft, Drunk Roll, >$950' 'Lynching by Riot'
#  'Lotteries (general)' 'Robbery, Chain Store, W/ Force'
#  'Burglary, Warehouse, Unlawful Entry'
#  'Loitering Without Lawful Business With Owner or Occupant'
#  'Public Nuisance, Committing' 'Post Release Community Supervision'
#  'Theft, Shoplifting, Att.' 'Driving, Failure To Heed Red Light And Siren'
#  'Weapon, Deadly, Carrying with Intent to Commit Assault'
#  'Robbery,  ATM, Knife' 'School Property, Disturbance on'
#  'Loitering Where Narcotics are Sold/Used'
#  'Violation of Emergency Protective Order' 'Theft, Trick & Device, Misd.'
#  'Alcohol, License Required To Sell' 'Assault on School Employee'
#  'Robbery, Att., W/ Gun'
#  'Weapon, Possess or Bring Other on School Grounds'
#  'Assault, Mayhem, W/ Force' 'Public Transit, Acts Against'
#  'Weapon, Carrying Concealed with Felony or Narcotics Conviction'
#  'Counterfeit Coins Or Notes, Possessing or Receiving'
#  'Burglary, Other Bldg. Under Constr., Att. Forcible'
#  'Unemployment Insurance Act Violation'
#  'Theft, Coin Operated Machine, $200-$950'
#  'Malicious Mischief, Breaking Windows With BB Gun'
#  'Burglary, Safe,  Store' 'Heroin Offense'
#  'Vehicle, Recovered, Mobile Home or House Trailer'
#  'Firearm, Possession of While Wearing Mask' 'VIN Switch'
#  'Firearm Possession in School Zone' 'Burglary, Safe, Other'
#  'Vehicle, Open Container Of Alcohol In' 'Accidental Lacerations'
#  'Access Card or Signature, Forgery of' 'Stolen Electronics, Possession'
#  'Electrical  or Gas Lines, Interfering with'
#  'Firearm, Negligent Discharge'
#  'Controlled Substance, Under the Influence of' 'Theft, Bicycle, Att.'
#  'School Campus, Remaining Without Consent'
#  'Burglary, Residence Under Constr, Att. Forcible' 'Cocaine Offense'
#  'Arson, Vacant Building' 'Assault, Att. Mayhem, W/ Other Weapon'
#  'Robbery, Att., Bank, W/ Force' 'Obstructions On Streets, Sidewalks'
#  'Burglary, Safe,  Residence' 'Robbery,  ATM, Other Weapon'
#  'Vehicle, Throwing Substance At' 'Permit Violation, Entertainment'
#  'Alcohol, Sale Of After Hours' 'Municipal Code Violation (general)'
#  'Liquor Law Violation (general)'
#  'Driving While Under The Influence Of Alcohol, w/Injury'
#  'Weapon, Assault, Registration or Transfer Violation'
#  'Purchase Female For The Purpose Of Prostitution' 'Engaging In Lewd Act'
#  'Lodging Without Permission' 'School, Public, Trespass'
#  'Robbery, Bank, W/ Force' 'Burglary, Apt Under Constr., Forcible Entry'
#  'Homicide, W/ Gun' 'Robbery, Bank, W/ Gun' 'Suicide'
#  'Dissuading/Threatening Of A Witness' 'Damage To Mail Box'
#  'Suicide By Ingestion, Att.' 'Robbery, Att., W/ Other Weapon'
#  'Fire Alarm, False' 'Theft, Boat' 'Accessory or Aid Or Harbor Felon'
#  'VIN, Alter Or Remove' 'Maintaining A Public Nuisance'
#  'Burglary, Vehicle, Att. (Arrest made)'
#  'Weapon, Assault, Possession, Manufacture, or Sale'
#  'Assault, Mayhem, W/ Knife' 'Riot, Inciting To'
#  'Methamphetamine, Transportation' 'Vehicle, Stolen, Bus'
#  'Permit Violation, Police (general)' 'Kidnapping during Carjacking'
#  'Theft, Purse Snatch, >$950' 'Fire Protection Equipment, Tampering with'
#  'Robbery, Att., Street or Public Place, W/ Gun'
#  'Suicide By Jumping, Att.' 'Civil Sidewalks, Citation'
#  'Robbery, Residence, W/ Force'
#  'Loitering and Peeking into Inhabited Structure' 'Dog, Stray or Vicious'
#  'Assault, Att. Homicide, W/ Force' 'Assault, Att. Homicide, W/ Knife'
#  'Looting during State of Emergency' 'Perjury' 'Robbery,  ATM, Force.'
#  'Animal, Poisoning of'
#  'Identification, Government, Possess, Make or Sell False'
#  'Disturbing The Peace, Swearing' 'Carjacking with a Dangerous Weapon'
#  'Theft, Vehicle Strip, <$50' 'Opium Derivative, Possession For Sale'
#  'Fireworks, Exploding'
#  'Fireworks, Possession of any within SF,  incl. "Safe & Sane"'
#  'Heroin, Sales' 'Embezzlement, Petty Theft By Employee'
#  'Weapon, Tear Gas, Possession by Prohibited Persons'
#  'Robbery, Att., Street or Public Place, W/ Knife'
#  'Firearm with Altered Identification' 'Theft, Vehicle Strip, $50-$200'
#  'Conceal Crime or Withhold Evidence, Accepting Payment to'
#  'School or Playground, Loitering About'
#  'Driving While Under The Influence Of Drugs, w/Injury'
#  'Firearm, Carrying Loaded with Intent to Commit Felony'
#  'Vehicle, Recovered, Bus' 'Telephone or Telegraph Message, Sending False'
#  'Advertisements, Affixing To Poles' 'Theft, Drunk Roll, $200-$950'
#  'Theft, Animal, Att.' 'Located Property'
#  'Burglary, Flat, Att. Forcible Entry' 'Escape or Assisting Escape'
#  'SFMTA Muni Transit Operator-Bus/LRV'
#  'Theft, Bicycle, <$50, serial number known'
#  'Probation Violation, DVU related' 'Firearm, Tampering With Marks'
#  'Firearm Transfer, Violation'
#  'Malicious Mischief, Building Under Constr.'
#  'Prescription, Forge Or Alter (11368 H&S)' 'Rape, Assault To, W/ Force'
#  'Robbery, Bank, W/ Other Weapon' 'Auto, Grand Theft of'
#  'Civil Sidewalks, Violation' 'Death, Non-manslaughter Vehicle Accident'
#  'Soliciting or Engaging In Lewd Conduct'
#  'Access Card Information, Publication of' 'Real Estate Fraud'
#  'Littering or Dumping that Creates Traffic Hazard'
#  'Hallucinogenics Offense' 'Civil Sidewalks, Warning'
#  'False Report of Felony or Misdemeanor' 'Aided Case, Sick Person'
#  'Stolen Cellular Phone, non-cloned, Possession'
#  'House of Prostitution, Keeping or Residing in'
#  'Theft of Written Instrument' 'Homicide, W/ Sharp Object'
#  'Driving, Reckless, with Injury'
#  'Burglary, Hotel Room, Att. Forcible Entry' 'Homicide'
#  'Weapon, Deadly, Exhibiting to Resist Arrest'
#  'Robbery, Att., Service Station, W/ Gun' 'Counterfeiting, Coins Or Notes'
#  'Military Ordinance' 'Dissuading Witness, Victim'
#  'Loitering for Purpose of Prostitution'
#  'SFMTA Parking and Control Officer'
#  'Machine Gun or Sawed-off Shotgun, Possession'
#  'Robbery, Att., Chain Store, W/ Other Weapon'
#  'Push-cart Peddler Permit Violation'
#  'Sexual Contact with Patient, former Patient'
#  'Caustic Chemical, Possession' 'Methadone Offense'
#  'Theft, Coin Operated Machine, >$950'
#  'Maintain Premise Where Narcotics Are Sold/used' 'Loitering, Obstructing'
#  'Dead Body, Removing Items from' 'Robbery, Att., Bank, W/ Gun'
#  'Burglary, Hotel Under Constr., Forcible Entry'
#  'Rape, Forcible, W/ Other Weapon' 'Cloned Cellular Phone, Use'
#  'Assault, Att. Mayhem, W/ Force' 'Rape, Att., W/ Force'
#  'Assault, Mayhem, W/ Gun' 'Assault During Labor Dispute'
#  'Stolen Checks, Possession' 'Theft, Coin Operated Machine, $50-$200'
#  'Obstructing Health Facility, Place of Worship, or School'
#  'Impersonating Public Utility Member' 'Manslaughter, Vehicular'
#  'Checks, Theft/Non-sufficient Funds, Felony' 'Unlawful Assembly'
#  'Destructive Device, Possession' 'Evading Payment of Railroad Fare'
#  'Explosive Device, Located' 'Stolen Access Card, Possession'
#  'Sexual Assault, Administering Drug to Commit' 'Dog, Barking'
#  'Vehicle, Disabled Placard Violation'
#  'Robbery, Service Station, W/ Force'
#  'Weapon, Deadly, Possession W/ Intent To Assault'
#  'Burglary, Warehouse Under Constr, Forcible Entry'
#  'Destructive Device, Exploding' 'Kidnapping, Attempted (Adult victim)'
#  'Theft, Motorcycle Strip, $200-$950' 'Gambling Devices, Possession'
#  'Records or Returns, False Entries' 'Explosives, Illegal Transportation'
#  'Theft, Purse Snatch, $200-$950' 'Financial Statements, False'
#  'Resisting Peace Officer, causing Their Serious Injury or Death'
#  'Theft of Telecommunication Services, incl. Clone Phone'
#  'Robbery, Residence, W/ Other Weapon'
#  'Crimes Against Revenue & Property of State'
#  'Hazardous Materials, Dumping in Unauthorized Location'
#  'Terrorizing by Arson or Explosive Device'
#  'Theft, Petty, with Prior Conviction' 'Defrauding Of Vehicle Repairman'
#  'Human Trafficking (A)-Commercial Sex Acts'
#  'Phone Calls, Harassing, to 911' 'Robbery, Att., Residence, W/ Force'
#  'Fire Code Violation (general)'
#  'Embezzlement, Grand Theft Leased Property' 'Arson, Portable Toilet'
#  'Public Health Order Violation, Notification'
#  'Drug Lab Apparatus, Possession' 'Theft, Motorcycle Strip, <$50'
#  'Gambling' 'Theft, Coin Operated Machine, <$50'
#  'Robbery,  ATM, Gun, Att.' 'Delivered Mail, Damage or Destruction of'
#  'Switchblade Knife, Possession' 'Cocaine, Sale'
#  'Robbery, Service Station W/ Other Weapon'
#  'Throwing Object at Common Carrier, Passenger or Freight'
#  'Robbery, Comml. Establ. W/ A Knife' 'Marijuana, Transporting'
#  'Dog or Cat, Abandonment of' 'Alcohol, Furnish or Sell to Intox. Person'
#  'Robbery, Att., Comm. Establ. W/ Knife' 'Driving, Drag Racing'
#  'Assault, Mayhem, W/ Other Weapon'
#  'Demonstration, Video Evidence, Misc Investigation'
#  'Robbery, Service Station, W/ Gun'
#  'Burglary, Apt Under Constr., Att. Forcible'
#  'Public Health Order Violation, After Notification'
#  'Penetration, Forced, with Object' 'Arson, Police Vehicle'
#  'Sodomy (Adult Victim)' 'Trash, Placing On The Street'
#  'School, Disrupt Activities' 'Robbery, Att., Chain Store, W/ Knife'
#  'Cocaine, Transportation' 'Robbery, Residence, W/ Knife'
#  'Firefighter, Interfering with' 'Theft, Purse Snatch, $50-$200'
#  'Police Broadcast, Interception to Commit Crime'
#  'Theft, Short Change, >$950'
#  'Burglary, Flat Under Constr., Unlawful Entry'
#  'Burglary, Flat Under Constr., Att. Forcible'
#  'Armor Penetrating Ammunition, Possession'
#  'Manufacture or Sale of Counterfeit Goods'
#  'Rape, Assault To, W/ Other Weapon'
#  'Suicide By Strangulation/Hanging, Att.'
#  'Burglary, Flat Under Constr., Forcible Entry'
#  'Phone Calls in Violation of DVU Court Order' 'Theft, Short Change'
#  'Robbery,  ATM, Other Weapon, Att.'
#  'Harbor & Navigations Code Violation (general)'
#  'Escape of Prisoner From Hospital'
#  'Controlled Substance Violation, Loitering for' 'Methadone, Sale'
#  'Opium Offense' 'Assault to Commit Mayhem or Specific Sex Offenses'
#  'Embezzlement, Grand Theft By Collector' 'Loitering near ATM'
#  'Heroin, Transportation'
#  'Fireworks, Throw at Person or Discharge in Crowd'
#  'Drugs, Under Influence  in a Public Place'
#  'Burglary, Hotel Under Constr., Unlawful Entry'
#  'Theft, By Prostitute, $200-$400' 'Vandalism with Noxious Chemical'
#  'Loitering Around Public Toilet For Lewd Act'
#  'Burglary, Warehouse Under Constr, Att. Forcible' 'Solicits Lewd Act'
#  'Theft, Pickpocket, Attempted' 'Animal, without Proper Care or Attention'
#  'Prescription, Forge Or Alter (4390 B&P)'
#  'Wearing Mask or Disguise for Unlawful Purpose'
#  'Hazardous Materials,  Dump any Substance into Water' 'Incest'
#  'Assault, Commission of While Armed' 'Theft, Phone Booth, <$50'
#  'Retaking Goods from Peace Officer'
#  'Alcoholic Beverage, Procuring Sale of'
#  'Gun Violence Restraining Order Violation' 'Abortion, Unlawful'
#  'Permit Violation, Advertising Distributors'
#  'Cable TV Connection or Decoding Device, Unauthorized'
#  'Stolen Computer, Possession' 'Theft, Purse Snatch, <$50'
#  'Parking Meters, Damage to'
#  'Weapon, Possessing in Public Building or Open Meeting'
#  'Theft, Motorcycle Strip, $50-$200'
#  'Falsifying Judicial & Public Records & Documents'
#  'Firearms, Seizing at Scene of DVU'
#  'Refusing To Disperse Upon Lawful Command' 'Suicide By Asphyxiation'
#  'Theft, Phone Booth, $200-$950' 'Balloons, Electrically Conductive'
#  'Embezzlement, Petty Theft Private Property' 'Suicide By Ingestion'
#  'Homicide By Sniping' 'Riot' 'Public Transit Crimes - Infractions'
#  'Kidnapping for Ransom or Extortion' 'Suicide By Fire, Att.'
#  'Soliciting Commission Of A Crime' 'Permit Violation, Sidewalk Sales'
#  'Robbery, Bank, W/ Knife' 'Theft, Phone Booth, $50-$200'
#  'Peddling Without A License' 'Violation of Civil Gang Injunction'
#  'Weapon, Concealed, Loitering While Carrying'
#  'Weapon, Taking or Attempting to Take from Peace Officer'
#  'Fire Bomb, Possession or Use' "Megan's Law Notification"
#  'Robbery, Service Station, W/ Knife' 'Obscene Movies or Acts'
#  'Disturbing Religious Meetings'
#  'Counterfeit/Forgery, Poss Drivers Lic Or Id Card'
#  'Robbery, Att., Residence, W/ Gun'
#  'Trespassing or Loitering Near Posted Industrial Property'
#  "Assault or Attempted Murder Upon Gov't Officers"
#  'Letters, Opening Sealed'
#  'Burglary, Warehouse Under Constr, Unlawful Entry' 'Amphetamines Offense'
#  'Aerosol Paint & Marker Pens, Display & Storage' 'Barbiturates Offense'
#  'Assault, Att. Homicide, Explosives' 'Soliciting, Aggressive'
#  'Rape, Assault To, W/ Sharp Object'
#  'Trade Secrets, Theft or Unauthorized Copying'
#  'Throwing Injurious Substance on Highway' 'Theft, Drunk Roll, $50-$200'
#  'Destructive Device, Possession of Materials'
#  'Terrorizing by Marking Private Property' 'Vehicle, Seizure Order'
#  'Robbery, Att., Service Station W/ Other Weapon'
#  'Trespassing On Railroad Trains' 'Burglary, Safe,  Hotel'
#  'Homicide, W/ Force' 'Escapes'
#  'Manslaughter, Accidental, W/ Other Weapon'
#  'SFMTA Employee-Non Operator/Station Agent-Other Employee'
#  'Escape From Hospital With Force'
#  'Terrorizing by Interfering with Religious Worship'
#  'Theft, Drunk Roll, <$50' 'Theft, Drunk Roll, Att.'
#  'Opium, Possession For Sale' 'Homicide, Excusable, W/ Sharp Object'
#  'Theft, By Prostitute, $50-$200'
#  'Money Offense Related to Narcotics Trafficking'
#  'Soliciting to Visit House Of Prostitution'
#  'Embezzlement, Grand Theft By Property Carrier'
#  'Theft, Purse Snatch, Att.' 'Lodging in Park'
#  'Robbery, Att., Chain Store, W/ Gun' 'Firearm Silencer, Possession'
#  'Civil Sidewalks, Booking' 'Labor Code Violation'
#  'Massage Establishment Permit Violation' 'Amphetamine, Transportation'
#  'Robbery, Att., Bank, W/ Knife' 'Opium Derivative Offense'
#  'Rape, Att., W/ Sharp Object' 'Eavesdropping Devices, Sale or Use'
#  'Arson with Great Bodily Injury'
#  'Indecent Exposure, Prostitution Related'
#  'Gambling Paraphernalia, Possession'
#  'Embezzlement, Grand Theft By Brokers/Agents' 'Stolen Metals, Receiving'
#  'Marijuana, Furnishing' 'Assault, By Police Officers'
#  'Theft, By Prostitute, <$50' 'Burglary, Safe,  Warehouse'
#  'Robbery, Att., Residence, W/ Knife'
#  'Theft, Grand, by Fiduciary, >$950 in 12 months'
#  'Bathroom Hole, Looking through'
#  'Embezzlement, Petty Theft, Leased Property'
#  'Robbery, Vehicle for Hire, Att., W/ Force'
#  'Endless Chain Schemes, Ponzi Schemes' 'Suicide By Laceration/Stabbing'
#  'Assault, Att. Mayhem, W/ Knife'
#  'Disturbance of Non-religious, Non-political Assembly'
#  'Embezzlement, Grand Theft Public/Private Official' 'Rape, Att., W/ Gun'
#  'Scalping Tickets' 'Telephone or Telegraph Messages, Altering'
#  'Embezzlement, Petty Theft By Brokers/Agents' 'Begging or Panhandling'
#  'Forgery, Government Or Corporate Seals'
#  'Civil Rights, incl. Injury, Threat, or Damage (Hate Crimes)'
#  'Sales of Cocaine Base/Schoolyard Trafficking Act Violation'
#  'Drug Offender, Presence  near School Grounds'
#  'Weapon, Deadly, Possession of to Violate 136.1 PC'
#  'VIN, Possess to Defraud' 'Citizenship Document, Using False'
#  'Legal Instruments, Uttering False Checks, etc. (misd.)'
#  'Loud Speakers, Unauthorized Use of' 'Threat to State Official or Judge'
#  'Narcotics Addict, Failure To Register'
#  'Embezzlement, Grand Theft Private Property'
#  'Disaster Area, Entering or Remaining in'
#  'Fighting Dog or Animal, Biting or Causing  Injury or Death'
#  'Chop Shop, Own or Operate' 'Sale or Manufacture of Deceptive ID'
#  'Homicide, W/ Other Weapon'
#  'Robbery, Vehicle for Hire, Att., W/ Other Weapon'
#  'Hypodermic Needle or Syringe, Possession'
#  'Contraband, Taking Into A Reformatory' 'Suicide By Asphyxiation, Att.'
#  'Rape, Spousal' 'Theft, Coin Operated Machine, Att.'
#  'School Student or Employee Entering  Campus after Suspension or Dismissal'
#  'Taxi Fare, Overcharging' 'Barbiturates, Possession'
#  'Prisoner, Rescuing From Lawful Custody'
#  'Robbery, Vehicle for Hire, Att., W/ Gun'
#  'Crimes Involving Receipts or Titles' 'Bribery Of Witnesses'
#  'Money Laundering' 'Burglary, Safe, Apartment'
#  'Guide Dog, Interfering with'
#  'Parking Meter, Unlawful Operation or Use of Slugs'
#  'School Grounds, Entry by Sex Offender'
#  'Dog, Fighting;  Owning, Fighting, or Attending Fight'
#  'Robbery, Att., Service Station W/ Force'
#  'Trespass within 30 days of Credible Threat' 'Methadone, Transportation'
#  'Robbery, Att., Residence, W/ Other Weapon'
#  'Rape, Forcible, W/ Sharp Object' 'Hallucinogenic, Transportation'
#  'Embezzlement, Petty Theft By Property Carrier'
#  'Robbery, Att., Service Station, W/ Knife' 'Wiretaps, Unauthorized'
#  'Soliciting Customer to Purchase Alcoholic Beverage'
#  'Rape, Forcible, W/ Gun' 'False Report of Police Misconduct'
#  'Procurement, Pimping, & Pandering' 'Assault, Att. Mayhem, W/ Gun'
#  'Rape, Assault To, W/ Gun'
#  'Human Trafficking (B)-Involuntary Servitude (not sex-related)'
#  'Burglary, Safe, Warehouse, with Explosives' 'Hotel Violations'
#  'Permit Violation, Dance Hall' 'Suicide By Firearms, Att.'
#  'Barbiturates, Transportation' 'Lodging, Registering w/False Name'
#  'Sale of Satellite Telephone Numbers'
#  'Bribery or Gratuity,  Public Employees' 'Suicide By Drowning, Att.'
#  'Obscene Or Lewd Plays/Performances'
#  'Articles With ID Removed, Possession of'
#  'Jail Property, Destroying (SFPD only)'
#  'Service of Documents Related to a Civil Drug Abatement and/or Public Nuisance Action'
#  'Pyrotechnic Explosive Device - Barrel Bomb'
#  'Rape, Att., W/ Other Weapon'
#  'Insured Property, Destruction to Defraud Insurer'
#  'Impersonating Fire Department Member'
#  'Burglary, Safe, Other, with Explosives'
#  'Barbiturates, Possession For Sale' 'Theft, Phone Booth, >$950'
#  'Accidental Burns' 'Controlled Substance, Presence Where Used']
# 842 unique values
# resolution:
# ['Open or Active' 'Cite or Arrest Adult' 'Exceptional Adult' 'Unfounded']
# 4 unique values
# police_district:
# ['Out of SF' 'Mission' 'Central' 'Park' 'Bayview' 'Richmond' 'Southern'
#  'Northern' 'Taraval' 'Tenderloin' 'Ingleside']
# 11 unique values
# filed_online:
# [nan  1.]
# 1 unique values
# cad_number:
# [           nan 2.30741133e+08 2.30742480e+08 ... 2.30801871e+08
#  2.30812759e+08 2.30812680e+08]
# 414462 unique values
# intersection:
# [nan 'STANYAN ST \\ HAYES ST' 'GEARY ST \\ POWELL ST' ...
#  'GATUN ALY \\ BELLA VISTA WAY' 'ELLIOT ST \\ LELAND AVE'
#  'WASHINGTON BLVD \\ COMPTON RD']
# 6382 unique values
# cnn:
# [      nan 26446000. 24903000. ... 32992000. 20383000. 51364000.]
# 6470 unique values
# analysis_neighborhood:
# [nan 'Golden Gate Park' 'Financial District/South Beach' 'Potrero Hill'
#  'Tenderloin' 'Pacific Heights' 'Bayview Hunters Point' 'Russian Hill'
#  'Marina' 'Mission' 'Outer Richmond' 'Chinatown' 'Sunset/Parkside'
#  'Haight Ashbury' 'South of Market' 'Portola' 'Nob Hill' 'North Beach'
#  'Inner Richmond' 'Noe Valley' 'Hayes Valley' 'West of Twin Peaks'
#  'Japantown' 'Lakeshore' 'Excelsior' 'Mission Bay' 'Inner Sunset'
#  'Castro/Upper Market' 'Outer Mission' 'Visitacion Valley'
#  'Bernal Heights' 'Twin Peaks' 'Western Addition' 'Lone Mountain/USF'
#  'Treasure Island' 'Seacliff' 'Presidio Heights'
#  'Oceanview/Merced/Ingleside' 'Glen Park' 'Lincoln Park' 'Presidio'
#  'McLaren Park' 'null']
# 42 unique values
# supervisor_district:
# [nan  1.  3. 10.  2.  9.  5.  4.  6.  8.  7. 11.]
# 11 unique values
# supervisor_district_2012:
# [nan  1.  3. 10.  6.  2.  9.  8.  4.  5.  7. 11.]
# 11 unique values
# latitude:
# [        nan 37.77289518 37.78735926 ... 37.73797691 37.71369702
#  37.79448897]
# 6470 unique values
# longitude:
# [          nan -122.45428512 -122.40822673 ... -122.44754108 -122.41160447
#  -122.47217803]
# 6470 unique values
# point:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#      10 for x in sfpd_incident_current.columns:
#      11     print(x+':')
# ---> 12     print(sfpd_incident_current[x].unique())
#      13     print(str(sfpd_incident_current[x].nunique()) + str(' unique values'))
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:2088, in Series.unique(self)
#    2030 def unique(self) -> ArrayLike:
#    2031     """
#    2032     Return unique values of Series object.
#    2033
#    (...)
#    2086     Categories (3, object): ['a' < 'b' < 'c']
#    2087     """
# -> 2088     return super().unique()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\base.py:989, in IndexOpsMixin.unique(self)
#     987             result = np.asarray(result)
#     988 else:
# --> 989     result = unique1d(values)
#     991 return result
#
# File ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py:440, in unique(values)
#     437 htable, values = _get_hashtable_algo(values)
#     439 table = htable(len(values))
# --> 440 uniques = table.unique(values)
#     441 uniques = _reconstruct_data(uniques, original.dtype, original)
#     442 return uniques
#
# File pandas\_libs\hashtable_class_helper.pxi:5361, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# File pandas\_libs\hashtable_class_helper.pxi:5310, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'dict'

# %%
print('\nSFPD Historical Incidents - Unique Values:')
for x in sfpd_incident_current.columns:
    print(x+':')
    print(sfpd_incident_current[x].unique())
    print(str(sfpd_incident_current[x].nunique()) + str(' unique values'))
